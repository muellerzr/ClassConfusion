# %% [markdown]
# # Images

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %%
path = untar_data(URLs.PETS)

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.876589</td>
#       <td>0.333644</td>
#       <td>0.097429</td>
#       <td>01:48</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## classLosses

# %%
# !git clone https://github.com/muellerzr/ClassLosses.git
# Out:
# Cloning into 'ClassLosses'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 138 (delta 75), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (138/138), 670.56 KiB | 930.00 KiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
from ClassLosses.classLosses import *

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
cl = ['Egyptian_Mau', 'Bengal','Russian_Blue', 'British_Shorthair' ]

# %%
ClassLosses(interp, cl)
# Out:
# Please enter a value for `k`: 5
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id1"></div>

# %% [markdown]
# # Tabular Data

# %%
from fastai.tabular import *

# %%
path = untar_data(URLs.ADULT_SAMPLE)
df = pd.read_csv(path/'adult.csv')

# %%
dep_var = 'salary'
cat_names = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race']
cont_names = ['age', 'fnlwgt', 'education-num']
procs = [FillMissing, Categorify, Normalize]

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                           .split_by_idx(list(range(800,1000)))
                           .label_from_df(cols=dep_var)
                           .databunch())

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)

# %%
learn.fit(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.372980</td>
#       <td>0.392199</td>
#       <td>0.800000</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## classLosses

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
clss = ['<50k', '>=50k']

# %%
ClassLosses(interp, clss)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id2"></div>
